# %%
# !git clone git@github.com:facebookresearch/segment-anything.git
# Out:
# Cloning into 'segment-anything'...
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive
# Out:
# /content/drive

# %%
ls
# Out:
# MyDrive/

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
# 'Assignment Cover Page.gdoc'  'Untitled document (1).gdoc'
# 'Assignment - IEL 1002.gdoc'  'Untitled document (2).gdoc'
# 'Colab Notebooks'/            'Untitled document.gdoc'

# %%
mkdir facebook-research

# %%
cd facebook-research/
# Out:
# /content/drive/MyDrive/facebook-research

# %%
# !git clone https://github.com/cs-joy/segment-anything.git
# Out:
# Cloning into 'segment-anything'...
# remote: Enumerating objects: 304, done.
# remote: Total 304 (delta 0), reused 0 (delta 0), pack-reused 304 (from 1)
# Receiving objects: 100% (304/304), 18.31 MiB | 8.60 MiB/s, done.
# Resolving deltas: 100% (161/161), done.

# %%
# !cd segment-anything && pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/facebook-research/segment-anything
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for segment_anything
# ...

# %%
ls -al
# Out:
# total 4
# drwx------ 9 root root 4096 Dec 23 18:23 segment-anything/

# %%
cd segment-anything/
# Out:
# /content/drive/MyDrive/facebook-research/segment-anything

# %%
ls
# Out:
# assets/             demo/      notebooks/  segment_anything/           setup.py
# CODE_OF_CONDUCT.md  LICENSE    README.md   segment_anything.egg-info/
# CONTRIBUTING.md     linter.sh  scripts/    setup.cfg

# %%
ls -al
# Out:
# total 58
# drwx------ 2 root root  4096 Dec 23 18:22 assets/
# -rw------- 1 root root  3541 Dec 23 18:22 CODE_OF_CONDUCT.md
# -rw------- 1 root root  1400 Dec 23 18:22 CONTRIBUTING.md
# drwx------ 4 root root  4096 Dec 23 18:22 demo/
# -rw------- 1 root root   211 Dec 23 18:22 .flake8
# drwx------ 8 root root  4096 Dec 23 18:22 .git/
# -rw------- 1 root root   389 Dec 23 18:22 .gitignore
# -rw------- 1 root root 11357 Dec 23 18:22 LICENSE
# -rw------- 1 root root   564 Dec 23 18:22 linter.sh
# drwx------ 3 root root  4096 Dec 23 18:22 notebooks/
# -rw------- 1 root root  9621 Dec 23 18:22 README.md
# drwx------ 2 root root  4096 Dec 23 18:22 scripts/
# drwx------ 4 root root  4096 Dec 23 18:22 segment_anything/
# drwx------ 2 root root  4096 Dec 23 18:23 segment_anything.egg-info/
# -rw------- 1 root root   371 Dec 23 18:22 setup.cfg
# -rw------- 1 root root   541 Dec 23 18:22 setup.py

# %%
pip install opencv-python

# %%
pip install pycocotools

# %%
pip install matplotlib

# %%
pip install onnxruntime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 61.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.4 MB/s eta 0:00:00
# ...

# %%
pip install onnx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 83.5 MB/s eta 0:00:00
# ...

# %%
ls
# Out:
# assets/             demo/      notebooks/  segment_anything/           setup.py
# CODE_OF_CONDUCT.md  LICENSE    README.md   segment_anything.egg-info/
# CONTRIBUTING.md     linter.sh  scripts/    setup.cfg

# %%
mkdir model_checkpoints

# %%
cd model_checkpoints/
# Out:
# /content/drive/MyDrive/facebook-research/segment-anything/model_checkpoints

# %%
ls

# %%
# !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Out:
# --2025-12-23 18:30:08--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.35.37.84, 13.35.37.123, 13.35.37.90, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.35.37.84|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2564550879 (2.4G) [binary/octet-stream]
# Saving to: ‘sam_vit_h_4b8939.pth’
#
# sam_vit_h_4b8939.pt 100%[===================>]   2.39G  58.3MB/s    in 39s
#
# 2025-12-23 18:30:47 (62.1 MB/s) - ‘sam_vit_h_4b8939.pth’ saved [2564550879/2564550879]

# %%
from segment_anything import sam_model_registry

# need to install the module first
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1345376625.py in <cell line: 0>()
# ----> 1 from segment_anything import sam_model_registry
#
# ModuleNotFoundError: No module named 'segment_anything'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pwd
# Out:
# '/content/drive/MyDrive/facebook-research/segment-anything/model_checkpoints'

# %%
cd ..
# Out:
# /content/drive/MyDrive/facebook-research/segment-anything

# %%
ls
# Out:
# assets/             LICENSE             README.md                   setup.cfg
# CODE_OF_CONDUCT.md  linter.sh           scripts/                    setup.py
# CONTRIBUTING.md     model_checkpoints/  segment_anything/
# demo/               notebooks/          segment_anything.egg-info/

# %%
ls scripts/
# Out:
# amg.py  export_onnx_model.py

# %%
mkdir inputImage && cd inputImage

# %%
cd inputImage
# Out:
# /content/drive/MyDrive/facebook-research/segment-anything/inputImage

# %%
cd ..
# Out:
# /content/drive/MyDrive/facebook-research/segment-anything

# %%
mkdir res_output

# %%
# !python scripts/amg.py --checkpoint model_checkpoints/sam_vit_h_4b8939.pth --model-type vit_h --input inputImage/img.jpg --output res_output/
# Out:
# Loading model...
# Processing 'inputImage/img.jpg'...
# [ WARN:0@38.415] global loadsave.cpp:1063 imwrite_ Unsupported depth image for selected encoder is fallbacked to CV_8U.
# Done!
